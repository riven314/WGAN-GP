# %% [markdown]
# ### Source
# source: https://github.com/wiseodd/generative-models/blob/master/GAN/wasserstein_gan/wgan_tensorflow.py
#
# ### WGAN v.s GAN
# - introduce weight clipping hyper-parameters
# - replace AdamOptimiser with RMSPropOptimiser
# - remove log(.) in loss function
# - smaller learning rate
# - remove sigmoid activation function for discriminator
#
# ### Claimed Advantage for WGAN
# - generator loss and discriminator loss are indicative of generated data performance/ convergence
# - improve the issue of mode collapse
#
# ### Disadvantage for WGAN
# - one more hyper-parameter, weight clipping
# - WGAN training run slower per epoch
#
# ### Log
# [15/03/2019]
# - 12000 epoches: mode collapse escaped, generated data spread out of mode. But generated data don't have separate mode
# - 30000 epoches: mode collapse escaped, generated data have wider spread. But no multi modes
# - 30000 epoches, 3 hidden layers: generated data look like parabola, line like, lie between 2 mode
#
# ### Questions
# 1. related to float scale? (i.e float64/ float128)

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os
import math
# %matplotlib inline

# %%
def xavier_init(size):
    in_dim = size[0]
    xavier_stddev = 1. / tf.sqrt(in_dim / 2.)
    return tf.random_normal(shape=size, stddev=xavier_stddev)

# %% [markdown]
# ### Parameters

# %%
epoch_n = 30000
dt_steps = 5
dg_steps = 1
mb_size = 256
X_dim = 2
z_dim = 2
h_dim = 16
w_clip = 0.01
lr = 5e-5

# %% [markdown]
# ### Data Steps

# %%
def generate_GMM(n):
    C = np.array([[0., -0.7], [3.5, .7]])
    g1 = np.random.randn(n, 2) + np.array([20, 20])
    g2 = np.random.randn(n, 2) + np.array([0, 10])
    g3 = np.dot(np.random.randn(n, 2), C)
    combine_g = np.vstack([g1, g2, g3])
    return combine_g

def sample_GMM(gen_GMM, n_samples):
    n_row = gen_GMM.shape[0]
    idx = np.random.randint(n_row, size = n_samples)
    return gen_GMM[idx, :]

# generate prior noise
def sample_z(m, n):
    return np.random.uniform(-1., 1., size = [m, n])

# %%
GMM_pop = generate_GMM(2000)

# %%
test_data = sample_GMM(GMM_pop, mb_size)
plt.scatter(test_data[:, 0], test_data[:, 1], c = 'r')
plt.title('Test data from real distribution');

# %% [markdown]
# ### Weight

# %%
X = tf.placeholder(tf.float32, shape=[None, X_dim])

D_W1 = tf.Variable(xavier_init([X_dim, h_dim]))
D_b1 = tf.Variable(tf.zeros(shape=[h_dim]))
D_W2 = tf.Variable(xavier_init([h_dim, h_dim]))
D_b2 = tf.Variable(tf.zeros(shape=[h_dim]))
D_W3 = tf.Variable(xavier_init([h_dim, h_dim]))
D_b3 = tf.Variable(tf.zeros(shape=[h_dim]))
D_W4 = tf.Variable(xavier_init([h_dim, 1]))
D_b4 = tf.Variable(tf.zeros(shape=[1]))

theta_D = [D_W1, D_W2, D_W3, D_W4, D_b1, D_b2, D_b3, D_b4]


Z = tf.placeholder(tf.float32, shape=[None, z_dim])

G_W1 = tf.Variable(xavier_init([z_dim, h_dim]))
G_b1 = tf.Variable(tf.zeros(shape=[h_dim]))
G_W2 = tf.Variable(xavier_init([h_dim, h_dim]))
G_b2 = tf.Variable(tf.zeros(shape=[h_dim]))
G_W3 = tf.Variable(xavier_init([h_dim, h_dim]))
G_b3 = tf.Variable(tf.zeros(shape=[h_dim]))
G_W4 = tf.Variable(xavier_init([h_dim, X_dim]))
G_b4 = tf.Variable(tf.zeros(shape=[X_dim]))

theta_G = [G_W1, G_W2, G_W3, G_W4, G_b1, G_b2, G_b3, G_b4]

# %% [markdown]
# ### Weight Clipping

# %%
# theta_D is list of D's params
clip_D = [p.assign(tf.clip_by_value(p, -w_clip, w_clip)) for p in theta_D]

# %% [markdown]
# ### Model Architecture

# %%
def generator(z):
    G_h1 = tf.nn.leaky_relu(tf.matmul(z, G_W1) + G_b1)
    G_h2 = tf.nn.leaky_relu(tf.matmul(G_h1, G_W2) + G_b2)
    G_h3 = tf.nn.leaky_relu(tf.matmul(G_h2, G_W3) + G_b3)
    output = tf.matmul(G_h3, G_W4) + G_b4    
    #G_prob = tf.nn.sigmoid(G_log_prob) # curse of mode collapse
    return output

def discriminator(x):
    D_h1 = tf.nn.leaky_relu(tf.matmul(x, D_W1) + D_b1)
    D_h2 = tf.nn.leaky_relu(tf.matmul(D_h1, D_W2) + D_b2)
    D_h3 = tf.nn.leaky_relu(tf.matmul(D_h2, D_W3) + D_b3)
    D_logit = tf.matmul(D_h3, D_W4) + D_b4
    #D_prob = tf.nn.sigmoid(D_logit)
    # remove sigmoid activation function
    D_prob = D_logit
    #D_prob = D_logit
    return D_prob, D_logit

# %%
G_sample = generator(Z)
D_real, D_logit_real = discriminator(X)
D_fake, D_logit_fake = discriminator(G_sample)

# %%
# alternative loss function
#D_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_logit_real, labels=tf.ones_like(D_logit_real)))
#D_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_logit_fake, labels=tf.zeros_like(D_logit_fake)))
#D_loss = D_loss_real + D_loss_fake
#G_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_logit_fake, labels=tf.ones_like(D_logit_fake)))

# modified loss function for WGAN
D_loss = -tf.reduce_mean(D_real) + tf.reduce_mean(D_fake)
G_loss = -tf.reduce_mean(D_fake)

# replace Adam by RMSProp
D_solver = tf.train.RMSPropOptimizer(learning_rate=lr).minimize(D_loss, var_list=theta_D)
G_solver = tf.train.RMSPropOptimizer(learning_rate=lr).minimize(G_loss, var_list=theta_G)

# %% [markdown]
# ### Training

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for it in range(epoch_n):
    # discriminator steps
    for _ in range(dt_steps):
        X_batch = sample_GMM(GMM_pop, mb_size)
        Z_batch = sample_z(mb_size, 2)
        # introduce weight clipping for WGAN
        _, D_loss_curr, _ = sess.run([D_solver, D_loss, clip_D], feed_dict={X: X_batch, Z: Z_batch})
    # generator step
    for _ in range(dg_steps):
        Z_batch = sample_z(mb_size, 2)
        _, G_loss_curr = sess.run([G_solver, G_loss], feed_dict={Z: Z_batch})

    if it % 1000 == 0:
        print("Iterations: %d\t Discriminator loss: %.4f\t Generator loss: %.4f"%(it, D_loss_curr, G_loss_curr))

print("Iterations: %d\t Discriminator loss: %.4f\t Generator loss: %.4f"%(it, D_loss_curr, G_loss_curr))
# Out:
# Iterations: 0	 Discriminator loss: 0.0000	 Generator loss: 0.0000
# Iterations: 1000	 Discriminator loss: -0.0003	 Generator loss: 0.0003
# Iterations: 2000	 Discriminator loss: -0.0002	 Generator loss: 0.0002
# Iterations: 3000	 Discriminator loss: -0.0002	 Generator loss: 0.0002
# Iterations: 4000	 Discriminator loss: -0.0001	 Generator loss: 0.0002
# Iterations: 5000	 Discriminator loss: -0.0001	 Generator loss: 0.0001
# Iterations: 6000	 Discriminator loss: -0.0001	 Generator loss: 0.0002
# Iterations: 7000	 Discriminator loss: -0.0000	 Generator loss: 0.0001
# Iterations: 8000	 Discriminator loss: -0.0000	 Generator loss: -0.0001
# Iterations: 9000	 Discriminator loss: -0.0000	 Generator loss: -0.0002
# Iterations: 10000	 Discriminator loss: -0.0000	 Generator loss: -0.0002
# Iterations: 11000	 Discriminator loss: -0.0000	 Generator loss: -0.0003
# Iterations: 12000	 Discriminator loss: -0.0000	 Generator loss: -0.0005
# Iterations: 13000	 Discriminator loss: -0.0000	 Generator loss: -0.0007
# Iterations: 14000	 Discriminator loss: -0.0000	 Generator loss: -0.0008
# Iterations: 15000	 Discriminator loss: -0.0000	 Generator loss: -0.0008
# Iterations: 16000	 Discriminator loss: -0.0000	 Generator loss: -0.0008
# Iterations: 17000	 Discriminator loss: -0.0000	 Generator loss: -0.0008
# Iterations: 18000	 Discriminator loss: -0.0000	 Generator loss: -0.0008
# Iterations: 19000	 Discriminator loss: -0.0000	 Generator loss: -0.0009
# Iterations: 20000	 Discriminator loss: -0.0000	 Generator loss: -0.0008
# Iterations: 21000	 Discriminator loss: -0.0000	 Generator loss: -0.0009
# Iterations: 22000	 Discriminator loss: -0.0000	 Generator loss: -0.0009
# Iterations: 23000	 Discriminator loss: -0.0000	 Generator loss: -0.0009
# Iterations: 24000	 Discriminator loss: -0.0000	 Generator loss: -0.0009
# Iterations: 25000	 Discriminator loss: -0.0000	 Generator loss: -0.0009
# Iterations: 26000	 Discriminator loss: -0.0000	 Generator loss: -0.0009
# Iterations: 27000	 Discriminator loss: -0.0000	 Generator loss: -0.0009
# Iterations: 28000	 Discriminator loss: -0.0000	 Generator loss: -0.0009
# Iterations: 29000	 Discriminator loss: -0.0000	 Generator loss: -0.0009
# Iterations: 29999	 Discriminator loss: -0.0000	 Generator loss: 0.0008

# %% [markdown]
# ### Visualization

# %%
z_samples = sample_z(mb_size, 2)
g_samples = sess.run(G_sample, feed_dict={Z: z_samples})
r_samples =  sample_GMM(GMM_pop, mb_size)

# %%
noise = plt.scatter(x = z_samples[:, 0], y = z_samples[:, 1], c = 'r', s = 12)
transform = plt.scatter(x = g_samples[:, 0], y = g_samples[:, 1], c = 'b', s = 12)
plt.legend((noise, transform), ('Prior Noise Sample', 'Generated Sample'))
#plt.ylim((0, 100))
plt.title('Prior Noise Samples v.s Generated Samples')
plt.tight_layout();

# %%
noise = plt.scatter(x = z_samples[:, 0], y = z_samples[:, 1], c = 'r', s = 12)
transform = plt.scatter(x = g_samples[:, 0], y = g_samples[:, 1], c = 'b', s = 12)
real = plt.scatter(r_samples[:, 0], r_samples[:, 1], c = 'g', s = 12)
plt.legend((noise, transform, real), ('Prior Noise Sample', 'Generated Sample', 'Real Samples'))
#plt.ylim((0, 100))
plt.title('Prior Noise Samples v.s Generated Samples v.s Real Samples')
plt.tight_layout();

# %% [markdown]
# ### Previous Performance

# %%
noise = plt.scatter(x = z_samples[:, 0], y = z_samples[:, 1], c = 'r', s = 12)
transform = plt.scatter(x = g_samples[:, 0], y = g_samples[:, 1], c = 'b', s = 12)
real = plt.scatter(r_samples[:, 0], r_samples[:, 1], c = 'g', s = 12)
plt.legend((noise, transform, real), ('Prior Noise Sample', 'Generated Sample', 'Real Samples'))
#plt.ylim((0, 100))
plt.title('Prior Noise Samples v.s Generated Samples v.s Real Samples')
plt.tight_layout();

# %%
def get_weights(param1, param2):
    param1_arr = np.array([])
    param2_arr = np.array([])
    for t_var in param1:
        tmp = sess.run(t_var).ravel().copy()
        param1_arr = np.hstack([tmp, param1_arr])
    for t_var in param2:
        tmp = sess.run(t_var).ravel().copy()
        param2_arr = np.hstack([tmp, param2_arr])
    return param1_arr, param2_arr

# %%
theta_D_arr, theta_G_arr = get_weights(theta_D, theta_G)

# %%
plt.hist(theta_D_arr, bins = 20)
plt.title('Discriminator Weights Histogram');

# %%
plt.hist(theta_G_arr, bins = 20)
plt.title('Discriminator Weights Histogram');
